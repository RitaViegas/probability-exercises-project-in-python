# %% [markdown]
# # Ejercicios de probabilidad

# %% [markdown]
# ## Ejercicio 1
#
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# - Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# - Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# - Divide el número del paso 2 entre el número de iteraciones(1000).

# %%
import numpy as np
import random
def dice_prob(rolls):
    counter = 0
    
    for _ in range (rolls):
        d1 = random.randint(1,6)
        d2 = random.randint(1,6)
        dice_sum = d1 + d2

        if dice_sum > 7 or dice_sum % 2 == 0:
            counter += 1
    return counter / rolls

probability = dice_prob(1000)

print(f"The probability of rolling a number greater than 7 or an even number is: {(probability* 100)}%")
# Out:
# The probability of rolling a number greater than 7 or an even number is: 66.0%

# %% [markdown]
# ## Ejercicio 2
#
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# 1. Tomar 3 blancas y 2 rojas.
# 2. Toas todas del mismo color.
#
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
import random

ball_box = {}

# Crea la cajas con las bolas
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"

print(ball_box)

# function to simulate the experiment            
def simulate_experiment(simulations):
    count_3_white_2_red = 0
    count_same_color = 0
    
    for _ in range(simulations):
        white = 0 
        red = 0
        green = 0

        # taking balls with replacement
        for _ in range (5):
            random_ball = random.randint (0,59)
            color = ball_box[random_ball]
            
            # counting the colors
            if color == "White":
                white += 1
            elif color == "Red":
                red += 1
            else:
                green += 1

        if white == 3 and red == 2:
            count_3_white_2_red += 1
        if white == 5 or red == 5 or green == 5:
            count_same_color += 1
        
    # probabilities calculation
    prob_3_w_2_r = (count_3_white_2_red / simulations) * 100
    prob_same_color = (count_same_color / simulations) * 100
        
    return prob_3_w_2_r, prob_same_color
    
prob_3_w_2_r, prob_same_color = simulate_experiment(1000)

print(f"The probability of getting 3 white balls and 2 red balls is: {prob_3_w_2_r}%")
print(f"The probability of getting 5 balls with the same color is: {prob_same_color}%")
# Out:
# {0: 'White', 1: 'White', 2: 'White', 3: 'White', 4: 'White', 5: 'White', 6: 'White', 7: 'White', 8: 'White', 9: 'White', 10: 'Red', 11: 'Red', 12: 'Red', 13: 'Red', 14: 'Red', 15: 'Red', 16: 'Red', 17: 'Red', 18: 'Red', 19: 'Red', 20: 'Red', 21: 'Red', 22: 'Red', 23: 'Red', 24: 'Red', 25: 'Red', 26: 'Red', 27: 'Red', 28: 'Red', 29: 'Red', 30: 'Green', 31: 'Green', 32: 'Green', 33: 'Green', 34: 'Green', 35: 'Green', 36: 'Green', 37: 'Green', 38: 'Green', 39: 'Green', 40: 'Green', 41: 'Green', 42: 'Green', 43: 'Green', 44: 'Green', 45: 'Green', 46: 'Green', 47: 'Green', 48: 'Green', 49: 'Green', 50: 'Green', 51: 'Green', 52: 'Green', 53: 'Green', 54: 'Green', 55: 'Green', 56: 'Green', 57: 'Green', 58: 'Green', 59: 'Green'}
# The probability of getting 3 white balls and 2 red balls is: 0.5%
# The probability of getting 5 balls with the same color is: 3.8%

# %%
import random
counter1 = 0
counter2 = 0

for _ in range(1000):
    white = 0
    red = 0
    green = 0

    for _ in range (5):
        bpick = random.randint(1,60)
        if bpick < 11:
            white += 1
        elif bpick < 31:
            red += 1
        else: 
            green += 1
    
    if (white == 3) and (red ==2):
        counter1 += 1
    if (white == 5) or (red == 5) or (green ==5):
        counter2 += 1

probabilidad_counter1 = (counter1/1000)*100
probabilidad_counter2 = (counter2/1000)*100
print(f"The probability of getting 3 white balls and 2 red balls is: {probabilidad_counter1}%")
print(f"The probability of getting 5 balls with the same color: {probabilidad_counter2}%")
# Out:
# The probability of getting 3 white balls and 2 red balls is: 0.6%
# The probability of getting 5 balls with the same color: 4.2%

# %%
counter1 = 0
counter2 = 0
colors = ['white'] * 10 + ['red'] * 20 + ['green'] * 30

for _ in range(1000):
    draw = random.choices(colors, k=5)
    white = draw.count('white')
    red = draw.count('red')
    green = draw.count('green')

    if white == 3 and red == 2:
        counter1 += 1
    if white == 5 or red == 5 or green == 5:
        counter2 += 1

probabilidad_counter1 = (counter1 / 1000) * 100
probabilidad_counter2 = (counter2 / 1000) * 100

print(f"The probability of getting 3 white balls and 2 red balls is: {probabilidad_counter1}%")
print(f"The probability of getting 5 balls with the same color: {probabilidad_counter2}%")
# Out:
# The probability of getting 3 white balls and 2 red balls is: 0.3%
# The probability of getting 5 balls with the same color: 3.8%
